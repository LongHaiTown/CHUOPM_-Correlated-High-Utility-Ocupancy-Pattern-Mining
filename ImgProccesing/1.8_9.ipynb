# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
#  Reading/ Displaying an image

# %%
# Color image
img = cv2.imread("./lasFotos/lovecanwait.jpg",-1)
img = img[:,:,::-1]
plt.imshow(img)

# Gray image
# img = cv2.imread("./lasFotos/lovecanwait.jpg",0)
# plt.imshow(img,cmap="gray")

plt.show()

# %% [markdown]
# Create random Img

# %%
array = np.random.randint(0,256,120000)
grayImg= array.reshape (300,400)
plt.imshow(grayImg,cmap='gray')

# %% [markdown]
# Accessing Img data with numpy

# %%
plt.imshow(img[500:700,200:760])

# %% [markdown]
# Crop image

# %%
crop = img[100:330, 100:330]
plt.imshow(crop)

# %% [markdown]
# Color changing

# %%
copy = img.copy()
copy[100:330, 100:330] = [255,0,0]
plt.imshow(copy)

# %%
array = np.random.randint(0,200 ,230*230*3)
censored = array.reshape(230,230,3)
copy[100:330, 100:330] = censored 
plt.imshow(copy)

# %% [markdown]
# Binary and Grayscale images

# %%
b,g,r = cv2.split(img) 
imgMerged = cv2.merge((b,g,r)) 
imgMerged= img[:,:,::-1]
plt.figure(figsize=(16,9))
plt.subplot(141)
plt.imshow(b,cmap='Blues');
plt.title("Blue channel") 
plt.subplot(142);
plt.imshow(g,cmap="Greens");
plt.title("Green channel") 
plt.subplot(143);
plt.imshow(r,cmap='Reds');
plt.title("Red channel") 
plt.subplot(144);
plt.imshow(imgMerged[:,:,::-1]);
plt.title("Merged Output")
# Out:
# Text(0.5, 1.0, 'Merged Output')

# %%
cam= cv2.VideoCapture(0)
while True:
    ret, frame = cam.read()
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) == ord("q"):
        break
cam.release()
cv2.destroyAllWindows()
