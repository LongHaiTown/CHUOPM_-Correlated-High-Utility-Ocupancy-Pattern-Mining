# %% [markdown]
# # Xử lý ảnh w/ OpenCV python

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %% [markdown]
# ### 6/9/2024

# %%
#Code
img = cv.imread("./lasFotos/lovecanwait.jpg",cv.IMREAD_GRAYSCALE)

#negative transformation
negative_img = 255 - img

#log transformation
c = 255 / np.log(1 + np.max(img))
log_img = c * np.log(1 + img)
log_img = np.array(log_img, dtype=np.uint8)

#plot
plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(img, cmap='gray')
plt.title("Original Img")
plt.axis("off")

#negative transformation
plt.subplot(1,3,2)
plt.imshow(negative_img,cmap='gray')
plt.title("Negative Img")
plt.axis("off")

#log transformation
plt.subplot(1, 3, 3)
plt.title("Log Transformation")
plt.imshow(log_img, cmap="gray")
plt.axis("off")
# Out:
# C:\Users\hthan\AppData\Local\Temp\ipykernel_11920\3032657862.py:8: RuntimeWarning: overflow encountered in scalar add
#   c = 255 / np.log(1 + np.max(img))
# C:\Users\hthan\AppData\Local\Temp\ipykernel_11920\3032657862.py:8: RuntimeWarning: divide by zero encountered in log
#   c = 255 / np.log(1 + np.max(img))
# C:\Users\hthan\AppData\Local\Temp\ipykernel_11920\3032657862.py:9: RuntimeWarning: divide by zero encountered in log
#   log_img = c * np.log(1 + img)
# C:\Users\hthan\AppData\Local\Temp\ipykernel_11920\3032657862.py:9: RuntimeWarning: invalid value encountered in multiply
#   log_img = c * np.log(1 + img)
# C:\Users\hthan\AppData\Local\Temp\ipykernel_11920\3032657862.py:10: RuntimeWarning: invalid value encountered in cast
#   log_img = np.array(log_img, dtype=np.uint8)
# (np.float64(-0.5), np.float64(959.5), np.float64(959.5), np.float64(-0.5))
